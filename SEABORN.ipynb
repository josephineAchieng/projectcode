# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_excel("cardata.xlsx")
df.head()
# Out:
#                Name  Min Price (Lakh)  Max Price (Lakh)  Range (kmpl)    CC  \
# 0     Mahindra Thar             11.35             17.60         15.20  1497
# 1      Maruti Swift              6.49              9.60         24.80  1197
# 2  Mahindra Scorpio             13.62             17.42         22.00  2184
# 3        Tata Punch              6.13             10.20         20.09  1199
# 4     Hyundai Creta             11.00             20.15         17.40  1497
#
#    Seats  Variants     Type  Ex-Showroom Price       RTO  Insurance  Other  \
# 0      4        19   Petrol            1430000  143000.0    84367.0  14300
# 1      5        11   Petrol             649000   46240.0    27791.0   5485
# 2      7         4  Diesel             1361600  175000.0    85943.0  27532
# 3      5        25   Petrol             612900   42903.0    35311.0      0
# 4      5        28   Petrol            1099900  116863.0    45300.0  11599
#
#   Onroad Price
# 0    16,71,667
# 1     7,28,516
# ...

# %%
variables =['Min Price (Lakh)','Max Price (Lakh)', 	'Range (kmpl)', 'CC' ,'Seats', 'Variants', 'Type', 	'Ex-Showroom Price', 'RTO', 'Insurance', 
            'Other','Onroad Price']

# %%
plt.figure(figsize=(15,12))
for i,var in enumerate(variables,start=1):
    plt.subplot(4,3,i)
    sns.scatterplot(x=df[var],y=df['Max Price (Lakh)'],alpha=0.7)
    plt.title(f'scatter plot of{var} vs Onroad Price')
    plt.xlabel(var)
    plt.ylabel('Target')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,10))
for i,var in enumerate(variables,start=1):
    plt.subplot(4,3,i)
    sns.histplot(df[var],bins=20,kde =True,color='blue')
    plt.title(f'histogram of{var} ')
    plt.xlabel(var)
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_excel("cardata.xlsx")
df.head()
# Out:
#                Name  Min Price (Lakh)  Max Price (Lakh)  Range (kmpl)    CC  \
# 0     Mahindra Thar             11.35             17.60         15.20  1497
# 1      Maruti Swift              6.49              9.60         24.80  1197
# 2  Mahindra Scorpio             13.62             17.42         22.00  2184
# 3        Tata Punch              6.13             10.20         20.09  1199
# 4     Hyundai Creta             11.00             20.15         17.40  1497
#
#    Seats  Variants     Type  Ex-Showroom Price       RTO  Insurance  Other  \
# 0      4        19   Petrol            1430000  143000.0    84367.0  14300
# 1      5        11   Petrol             649000   46240.0    27791.0   5485
# 2      7         4  Diesel             1361600  175000.0    85943.0  27532
# 3      5        25   Petrol             612900   42903.0    35311.0      0
# 4      5        28   Petrol            1099900  116863.0    45300.0  11599
#
#   Onroad Price
# 0    16,71,667
# 1     7,28,516
# ...

# %%
 #example data
box = [12,15,14,10,9,8,7,21,25,26,28,50,100]
 #create a box plot
sns.boxplot(data=box)
 #showing the plot
plt.show()

# %%
boxplot=df['Other']
sns.boxplot(data=boxplot)
plt.show()

# %%
box=df['Insurance']
sns.boxplot(data=box)
plt.show()

# %%
sns.boxplot(data=df,x='Type',y='Range (kmpl)', hue ='Type',palette =['Green','red'])
plt.title('Boxplot of Range by car type')
plt.show()

# %%
df.columns
# Out:
# Index(['Name', 'Min Price (Lakh)', 'Max Price (Lakh)', 'Range (kmpl)', 'CC',
#        'Seats', 'Variants', 'Type', 'Ex-Showroom Price', 'RTO', 'Insurance',
#        'Other', 'Onroad Price'],
#       dtype='object')

# %%
  selected_column=([ 'Min Price (Lakh)', 'Max Price (Lakh)', 'Range (kmpl)', 'CC', 'Seats', 'Variants', 'Ex-Showroom Price', 'RTO', 'Insurance',
       'Other',])
df_selected = df[selected_column]

# %%
corr=df_selected.corr()
corr
# Out:
#                    Min Price (Lakh)  Max Price (Lakh)  Range (kmpl)        CC  \
# Min Price (Lakh)           1.000000          0.648889     -0.610690  0.297886
# Max Price (Lakh)           0.648889          1.000000     -0.638677  0.564588
# Range (kmpl)              -0.610690         -0.638677      1.000000 -0.552374
# CC                         0.297886          0.564588     -0.552374  1.000000
# Seats                      0.060526         -0.130558      0.077048  0.437497
# Variants                  -0.017067         -0.135011     -0.089695 -0.300603
# Ex-Showroom Price          0.236930          0.882190     -0.503218  0.660969
# RTO                        0.168167          0.845523     -0.464982  0.666759
# Insurance                  0.256932          0.885078     -0.521480  0.692676
# Other                      0.248201          0.879881     -0.494726  0.695737
#
#                       Seats  Variants  Ex-Showroom Price       RTO  Insurance  \
# ...

# %%
sns.heatmap(corr, annot=True,cmap='BuPu')
plt.title('Heatmap of correlation Matrix')
plt.show()

# %%
sns.violinplot(data=df, x ='Type', y ='Max Price (Lakh)',hue='Type' , palette=['purple','Blue'])
plt.title('Violin Plot of Maximum price by Car')
plt.show()

# %%
sns.violinplot(data=df, x ='Type', y ='Range (kmpl)',hue='Type' , palette=['red','Indigo'])
plt.title('Violin Plot of range  by Type')
plt.show()

# %%
 selected_column=([ 'Min Price (Lakh)', 'Max Price (Lakh)', 'Range (kmpl)', 'CC', 'Seats', 'Variants', 'Ex-Showroom Price', 'RTO', 'Insurance',
       'Other' ,'Type'])
df_selected = df[selected_column]

# %%
sns.pairplot(df_selected,hue ='Type')
plt.suptitle('Pairplot of cardaset',y=1.02)
plt.show()

# %%
sns.pairplot(df_selected)
plt.suptitle('Pairplot of cardaset',y=1.02)
plt.show()
